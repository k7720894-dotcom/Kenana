# %%
def encryption (text,key):
    cipher_text=""
    for char in text:
        offset = (ord(char) - ord('a') + key) % 26 
        cipher_text += chr(ord('A')+ offset)
    return cipher_text

# %%
def decryption (text,key):
    plain_text=""
    for char in text:
        offset = (ord(char) - ord('A') - key) % 26
        plain_text += chr(ord('a') + offset)
    return plain_text

# %%
def bruteForce (ciphertext):
    for key in range(26):
        decrypted= decryption (text,key)
        print(f"key{key:2d}:{decrypted}")
